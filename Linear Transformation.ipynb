# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import cv2

# %%
def T(v):
    w=np.zeros((3,1))
    w[0,0] = 3*v[0,0]
    w[2,0] = -2*[1,0]

    return w

v = np.array([[3], [5]])
print("Original vector: ", v)
w = T(v)
print("Tranformed vector:", w)

# %%
def T(v):
    w = np.zeros((3,1))
    w[0,0] = 3*v[0,0]
    w[2,0] = -2*v[1,0]
    
    return w

v = np.array([[3], [5]])
w = T(v)

print("Original vector:\n", v, "\n\n Result of the transformation:\n", w)
# Out:
# Original vector:
#  [[3]
#  [5]]
#
#  Result of the transformation:
#  [[  9.]
#  [  0.]
#  [-10.]]
