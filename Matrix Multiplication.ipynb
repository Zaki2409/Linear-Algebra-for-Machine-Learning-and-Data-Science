# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

# %%
matA = np.array (
    [ [4, 9, 9],
      [9, 1, 6],
      [9, 2, 3]
    ]
)
print(matA)
# Out:
# [[4 9 9]
#  [9 1 6]
#  [9 2 3]]

# %%
matB = np.array(
    [
        [2, 2],
        [5, 7],
        [4, 4]
    ]
)
print(matB)
# Out:
# [[2 2]
#  [5 7]
#  [4 4]]

# %%
np.matmul(matA, matB)
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])

# %%
matA @ matB
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])

# %%
try:
    matA @ matB
except ValueError as er:
    print(er)

# %%
x = np.array([1, -2, -5])
y = np.array([4, 3, -1])

print("Shape of vaector x:", x.shape)
print("Shape fo vector y:", y.shape)
print("Num of Dimension of vector c:", x.ndim)
# Out:
# Shape of vaector x: (3,)
# Shape fo vector y: (3,)
# Num of Dimension of vector c: 1

# %%
print("Shape of vecotr X, reshaped to a matrix", x.reshape((3,1)).shape)
print("Number oif dimenstion of vector X, reshaped to a matric", x.reshape((3,1)).ndim)
# Out:
# Shape of vecotr X, reshaped to a matrix (3, 1)
# Number oif dimenstion of vector X, reshaped to a matric 2

# %%
np.matmul(x,y)
# Out:
# np.int64(3)

# %%
np.dot(matA, matB)
# Out:
# array([[ 89, 107],
#        [ 47,  49],
#        [ 40,  44]])
